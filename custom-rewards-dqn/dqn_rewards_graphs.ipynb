# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ## Vanilla DQN Training (for Reference)

# %%
# vanilla DQN# Load the CSV
df = pd.read_csv("../episode_stats.csv")  # replace with your actual filename
print(df['steps'])

# Create the plot
fig, ax1 = plt.subplots()
fig.set_figheight = 7
fig.set_figwidth = 12


# Plot total_reward on the primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(df['episode'], df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for avg_loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(df['episode'], df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Add title and show
plt.title('Episode vs Total Reward and Avg Loss')
fig.tight_layout()
plt.show()
# Out:
# 0       [175, 175]
# 1       [175, 175]
# 2       [175, 175]
# 3       [175, 175]
# 4       [175, 175]
#            ...
# 2995    [175, 175]
# 2996    [175, 175]
# 2997    [175, 175]
# 2998    [175, 175]
# 2999    [175, 175]
# Name: steps, Length: 3000, dtype: object

# %% [markdown]
# ## DQN with Reward Shaping

# %% [markdown]
# ### Reward Function 1, Small Env

# %%
# Load the CSV
reward_df = pd.read_csv("reward_episode_stats.csv")  # replace with your actual filename

# %%
# Create the plot
fig, ax1 = plt.subplots()
fig.set_figwidth = 12


# Plot total_reward on the primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(reward_df['episode'], reward_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for avg_loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(reward_df['episode'], reward_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Add title and show
plt.title('Episode vs Total Reward and Avg Loss')
fig.tight_layout()
plt.grid()
plt.show()

# %%
# Load the CSV
reward_df2 = pd.read_csv("reward_eval_stats.csv")  # replace with your actual filename

# %%
# Plot the total_rewards
plt.plot(reward_df2['step'],reward_df2['total reward'])
plt.title('Return Over Step')
plt.xlabel('Step')
plt.grid()
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')

# %% [markdown]
# ### Reward Function 2, Small Env

# %%
# Load the CSV
reward2_df = pd.read_csv("reward2_episode_stats.csv")  # replace with your actual filename

# %%
# Create the plot
fig, ax1 = plt.subplots()
fig.set_figwidth = 12


# Plot total_reward on the primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(reward2_df['episode'], reward2_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for avg_loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(reward2_df['episode'], reward2_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Add title and show
plt.title('Episode vs Total Reward and Avg Loss')
fig.tight_layout()
plt.grid()
plt.show()

# %%
# Load the CSV
reward2_df2 = pd.read_csv("reward2_eval_stats.csv")  # replace with your actual filename

# %%
# Plot the total_rewards
plt.plot(reward_df2['step'],reward_df2['total reward'])
plt.title('Return Over Step')
plt.xlabel('Step')
plt.ylabel('Return')
plt.grid()

# %% [markdown]
# ### Reward Function 3, Small Env

# %%
# Load the CSV
reward3_df = pd.read_csv("reward3_episode_stats.csv")  # replace with your actual filename

# Create the plot
fig, ax1 = plt.subplots()
fig.set_figwidth = 12


# Plot total_reward on the primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(reward3_df['episode'], reward3_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for avg_loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(reward3_df['episode'], reward3_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Add title and show
plt.title('Episode vs Total Reward and Avg Loss')
fig.tight_layout()
plt.grid()
plt.show()

# %%
# Load the CSV
reward3_df2 = pd.read_csv("reward3_eval_stats.csv")  # replace with your actual filename
# Plot the total_rewards
plt.plot(reward3_df2['step'],reward3_df2['total reward'])
plt.title('Reward Over Step')
plt.xlabel('Step')
plt.ylabel('Reward')
plt.grid()

# %%
# Load data
reward3_df = pd.read_csv("reward3_episode_stats.csv")
reward3_df2 = pd.read_csv("reward3_eval_stats.csv")

# Create subplots with 1 row and 2 columns
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 5))  # Adjust width as needed

# ---- Left Plot (Episode vs Total Reward and Avg Loss) ----
# Primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(reward3_df['episode'], reward3_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Secondary y-axis
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(reward3_df['episode'], reward3_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax1.set_title('Episode vs Total Reward and Avg Loss')
ax1.grid(True)

# ---- Right Plot (Step vs Total Reward) ----
ax3.plot(reward3_df2['step'], reward3_df2['total reward'], color='tab:green')
ax3.set_title('Reward Over Step')
ax3.set_xlabel('Step')
ax3.set_ylabel('Reward')
ax3.grid(True)

# Adjust layout
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Medium Env

# %%
# Load the CSV
medium_reward3_df = pd.read_csv("med_reward3_episode_stats.csv")  # replace with your actual filename

# Create the plot
fig, ax1 = plt.subplots()
fig.set_figwidth = 12


# Plot total_reward on the primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(medium_reward3_df['episode'], medium_reward3_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for avg_loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(medium_reward3_df['episode'], medium_reward3_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Add title and show
plt.title('Episode vs Total Reward and Avg Loss')
fig.tight_layout()
plt.grid()
plt.show()

# %%
# Load the CSV
med_reward3_df2 = pd.read_csv("med_reward3_eval_stats.csv")  # replace with your actual filename
# Plot the total_rewards
plt.plot(med_reward3_df2['step'],med_reward3_df2['total reward'])
plt.title('Return Over Step')
plt.xlabel('Step')
plt.ylabel('Return')
plt.grid()

# %%
# Load data
reward3_df = pd.read_csv("med_reward3_episode_stats.csv")
reward3_df2 = pd.read_csv("med_reward3_eval_stats.csv")

# Create subplots with 1 row and 2 columns
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 5))  # Adjust width as needed

# ---- Left Plot (Episode vs Total Reward and Avg Loss) ----
# Primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(reward3_df['episode'], reward3_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Secondary y-axis
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(reward3_df['episode'], reward3_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax1.set_title('Episode vs Total Reward and Avg Loss')
ax1.grid(True)

# ---- Right Plot (Step vs Total Reward) ----
ax3.plot(reward3_df2['step'], reward3_df2['total reward'], color='tab:green')
ax3.set_title('Reward Over Step')
ax3.set_xlabel('Step')
ax3.set_ylabel('Reward')
ax3.grid(True)

# Adjust layout
fig.tight_layout()
plt.show()

# %%
# Load data
reward3_df = pd.read_csv("reward2_episode_stats.csv")
reward3_df2 = pd.read_csv("reward2_eval_stats.csv")

# Create subplots with 1 row and 2 columns
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 5))  # Adjust width as needed

# ---- Left Plot (Episode vs Total Reward and Avg Loss) ----
# Primary y-axis
color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Total Reward', color=color)
ax1.plot(reward3_df['episode'], reward3_df['total_reward'], label='Total Reward', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Secondary y-axis
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Avg Loss', color=color)
ax2.plot(reward3_df['episode'], reward3_df['avg_loss'], label='Avg Loss', color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax1.set_title('Episode vs Total Reward and Avg Loss')
ax1.grid(True)

# ---- Right Plot (Step vs Total Reward) ----
ax3.plot(reward3_df2['step'], reward3_df2['total reward'], color='tab:green')
ax3.set_title('Reward Over Step')
ax3.set_xlabel('Step')
ax3.set_ylabel('Reward')
ax3.grid(True)

# Adjust layout
fig.tight_layout()
plt.show()
